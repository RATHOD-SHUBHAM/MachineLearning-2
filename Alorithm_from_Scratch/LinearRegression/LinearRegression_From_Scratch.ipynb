# %%
import numpy as np

# %%
class LinearRegression:
  def __init__(self, lr=0.01, n_iter = 1000):
    self.lr = lr
    self.n_iter = n_iter
    self.weights = None
    self.bias = None

  def fit(self, X, y):
    n_samples, n_features = X.shape

    self.weights = np.random.randn(n_features)

    self.bias = 0

    for i in range(self.n_iter):
      # Forward pass
      y_pred = np.dot(X, self.weights) + self.bias

      # Compute loss
      loss = (1 / (2 * n_samples)) * np.sum(y_pred - y) ** 2

      # Back Propagation
      # Gradient of loss w.r.t weights
      dw = (1 / n_samples) * np.dot(X.T, (y_pred - y))

      # Gradient of loss w.r.t bias
      db = (1 / n_samples) * np.sum(y_pred - y)

      # -------- Parameter Update --------
      self.weights = self.weights - self.lr * dw
      self.bias = self.bias - self.lr * db

      # Optional: print loss
      if i % 100 == 0:
          print(f"Iteration {i}, Loss: {loss:.4f}")

    return self

  def predict(self, X):
    y_pred = np.dot(X, self.weights) + self.bias

    return y_pred

# %% [markdown]
# **X.shape** is a property used to return a tuple representing the dimensions of an array or matrix X.
#
# - **Format**: It returns (n_samples, n_features).
#
# **Meaning:**
#
# - **n_samples (rows)**: The number of data points or observations.
# - **n_features (columns)**: The number of variables or features for each observation.
#
#
# **Example:** If X.shape is (100, 5), it means there are 100 samples, each with 5 features.

# %% [markdown]
# The **np.random.randn()** function in the NumPy library returns a sample (or samples) from the **standard normal (Gaussian) distribution**, which has a `mean of 0` and a `standard deviation of 1`.

# %%
import numpy as np
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# Generate a regression dataset
X, y = make_regression(
    n_samples=1000,      # number of data points
    n_features=1,       # number of features (x1, x2, x3)
    noise=10,           # add noise to make it realistic
    random_state=42
)

print("X shape:", X.shape)  # (100, 3)
print("y shape:", y.shape)  # (100,)
# Out:
# X shape: (1000, 1)
# y shape: (1000,)

# %%
fig = plt.figure(figsize=(8,6))
plt.scatter(X[:, 0], y, color = "b", marker = "o", s = 30)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LinearRegression(lr=0.001) # You can explicitly pass lr, or leave it as LinearRegression() to use the default

model.fit(X_train,y_train)

y_test_predictions = model.predict(X_test)
# Out:
# Iteration 0, Loss: 173.4381
# Iteration 100, Loss: 121.3827
# Iteration 200, Loss: 83.7806
# Iteration 300, Loss: 56.8795
# Iteration 400, Loss: 37.8515
# Iteration 500, Loss: 24.5742
# Iteration 600, Loss: 15.4625
# Iteration 700, Loss: 9.3389
# Iteration 800, Loss: 5.3338
# Iteration 900, Loss: 2.8097

# %%
def mse(y_test, predictions):
    return np.mean((y_test - predictions) ** 2)

# %%
calculated_mse = mse(y_test, y_test_predictions)
print(f"Mean Squared Error (MSE): {calculated_mse:.4f}")
# Out:
# Mean Squared Error (MSE): 135.9705

# %%
y_pred_line = model.predict(X)
cmap = plt.get_cmap('viridis')
fig = plt.figure(figsize=(8,6))
m1 = plt.scatter(X_train, y_train, color=cmap(0.9), s=10, label='Training data')
m2 = plt.scatter(X_test, y_test, color=cmap(0.5), s=10, label='Test data')
plt.plot(X, y_pred_line, color='black', linewidth=2, label='Prediction')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Linear Regression Model Fit')
plt.legend()
plt.show()

# %%
model = LinearRegression(lr=0.01) # You can explicitly pass lr, or leave it as LinearRegression() to use the default

model.fit(X_train,y_train)

y_test_predictions = model.predict(X_test)
# Out:
# Iteration 0, Loss: 162.2889
# Iteration 100, Loss: 1.2139
# Iteration 200, Loss: 0.8866
# Iteration 300, Loss: 0.7278
# Iteration 400, Loss: 0.2547
# Iteration 500, Loss: 0.0664
# Iteration 600, Loss: 0.0149
# Iteration 700, Loss: 0.0030
# Iteration 800, Loss: 0.0006
# Iteration 900, Loss: 0.0001

# %%
def mse(y_test, predictions):
    return np.mean((y_test - predictions) ** 2)

# %%
calculated_mse = mse(y_test, y_test_predictions)
print(f"Mean Squared Error (MSE): {calculated_mse:.4f}")
# Out:
# Mean Squared Error (MSE): 104.3820

# %%
y_pred_line = model.predict(X)
cmap = plt.get_cmap('viridis')
fig = plt.figure(figsize=(8,6))
m1 = plt.scatter(X_train, y_train, color=cmap(0.9), s=10, label='Training data')
m2 = plt.scatter(X_test, y_test, color=cmap(0.5), s=10, label='Test data')
plt.plot(X, y_pred_line, color='black', linewidth=2, label='Prediction')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Linear Regression Model Fit')
plt.legend()
plt.show()

# %%
model = LinearRegression(lr=0.1) # You can explicitly pass lr, or leave it as LinearRegression() to use the default

model.fit(X_train,y_train)

y_test_predictions = model.predict(X_test)
# Out:
# Iteration 0, Loss: 155.2829
# Iteration 100, Loss: 0.0000
# Iteration 200, Loss: 0.0000
# Iteration 300, Loss: 0.0000
# Iteration 400, Loss: 0.0000
# Iteration 500, Loss: 0.0000
# Iteration 600, Loss: 0.0000
# Iteration 700, Loss: 0.0000
# Iteration 800, Loss: 0.0000
# Iteration 900, Loss: 0.0000

# %%
def mse(y_test, predictions):
    return np.mean((y_test - predictions) ** 2)

# %%
calculated_mse = mse(y_test, y_test_predictions)
print(f"Mean Squared Error (MSE): {calculated_mse:.4f}")
# Out:
# Mean Squared Error (MSE): 104.3826

# %%
y_pred_line = model.predict(X)
cmap = plt.get_cmap('viridis')
fig = plt.figure(figsize=(8,6))
m1 = plt.scatter(X_train, y_train, color=cmap(0.9), s=10, label='Training data')
m2 = plt.scatter(X_test, y_test, color=cmap(0.5), s=10, label='Test data')
plt.plot(X, y_pred_line, color='black', linewidth=2, label='Prediction')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Linear Regression Model Fit')
plt.legend()
plt.show()

# %% [markdown]
# # Using Sklearn

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_test_pred = lr_model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_test_pred)
print(f"Mean Squared Error (MSE): {mse}")
# Out:
# Mean Squared Error (MSE): 104.3825519559741

# %%
y_pred_line = lr_model.predict(X)

cmap = plt.get_cmap('viridis')

fig = plt.figure(figsize=(8,6))

m1 = plt.scatter(X_train, y_train, color=cmap(0.9), s=10, label='Training data')
m2 = plt.scatter(X_test, y_test, color=cmap(0.5), s=10, label='Test data')
plt.plot(X, y_pred_line, color='black', linewidth=2, label='Prediction')

plt.xlabel('Feature')
plt.ylabel('Target')
plt.title('Linear Regression Model Fit')
plt.legend()
plt.show()
